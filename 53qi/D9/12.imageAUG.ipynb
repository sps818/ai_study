# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # tf.image进行增强

# %%
cat = plt.imread('./cat.jpg')

# %%
plt.imshow(cat)

# %%
cat1 = tf.image.random_flip_left_right(cat)
plt.imshow(cat1)

# %%
cat2 = tf.image.random_flip_up_down(cat)
plt.imshow(cat2)

# %%
cat3 = tf.image.random_crop(cat,(200,100,3))
plt.imshow(cat3)

# %%
cat4 = tf.image.random_brightness(cat,0.1)
plt.imshow(cat4)

# %%
cat5 = tf.image.random_hue(cat,0.2)
plt.imshow(cat5)

# %% [markdown]
# # 使用imagedataGenerator进行增强

# %%
from tensorflow.keras.datasets import mnist

# %%
# 获取数据集
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# 将数据转换为4维的形式
x_train = x_train.reshape(x_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)

# %%
# 实例化
datagen = tf.keras.preprocessing.image.ImageDataGenerator(shear_range=10,
                                                         rotation_range=15,
                                                         width_shift_range=0.3,
                                                         height_shift_range=0.4)

# %%
for x,y in datagen.flow(x_train,y_train,batch_size=9):
    plt.figure(figsize=(8,8))
    for i in range(0,9):
        plt.subplot(330+1+i)
        plt.imshow(x[i].reshape(28,28),cmap='gray')
        plt.title(y[i])
    plt.show()
    break
