# %%
# 设置环境变量，解决 OMP 错误
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %% [markdown]
# ### 1. Matplotlib
# - pip install matplotlib -U

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# 1. 读取图像
img = plt.imread(fname="cat.jpg")

# %%
# [H, W, C] RGB
img.shape
# Out:
# (218, 284, 3)

# %%
# 2. 图像显示
plt.imshow(X=img)

# %%
# 处理1：读取 R 层
img_r = img[:, :, 0]

# %%
img_r
# Out:
# array([[221, 221, 221, ...,  53,  58,  64],
#        [221, 221, 221, ...,  50,  59,  67],
#        [221, 221, 221, ...,  54,  65,  74],
#        ...,
#        [161, 133, 130, ...,  83,  98,  98],
#        [129, 152, 123, ...,  67,  85,  87],
#        [117, 153, 118, ...,  60,  83,  90]], dtype=uint8)

# %%
plt.imshow(X=img_r, cmap="gray")

# %%
# 处理2：截取图像上半部分

# %%
H, W, C = img.shape

# %%
plt.imshow(X=img[:H//2, :, :])

# %%
# 右侧半张图像
plt.imshow(X=img[:, W//2:, :])

# %%
# 处理3：左下角 1/ 4
plt.imshow(X=img[H//2:, :W//2, :])

# %%
# 亚采样
plt.imshow(X=img[::4, ::4, :])

# %%
# 保存
plt.imsave(fname="cat1.jpg", arr=img[::4, ::4, :])

# %% [markdown]
# ### 2. PIL

# %%
from PIL import Image

# %%
img = Image.open(fp="cat.jpg")

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=284x218>

# %%
dir(img)
# Out:
# ['_Image__transformer',
#  '__annotations__',
#  '__array_interface__',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_close_exclusive_fp_after_loading',
#  '_close_fp',
#  '_copy',
#  '_crop',
#  '_dump',
#  '_ensure_mutable',
#  '_exclusive_fp',
#  '_exif',
#  '_exif_offset',
#  '_expand',
#  '_get_safe_box',
#  '_getexif',
#  '_getmp',
#  '_huffman_ac',
#  '_huffman_dc',
#  '_im',
#  '_min_frame',
#  '_mode',
#  '_new',
#  '_open',
#  '_read_dpi_from_exif',
#  '_reload_exif',
#  '_repr_image',
#  '_repr_jpeg_',
#  '_repr_png_',
#  '_repr_pretty_',
#  '_seek_check',
#  '_size',
#  'alpha_composite',
#  'app',
#  'applist',
#  'apply_transparency',
#  'bits',
#  'close',
#  'convert',
#  'copy',
#  'crop',
#  'custom_mimetype',
#  'decoderconfig',
#  'decodermaxblock',
#  'draft',
#  'effect_spread',
#  'encoderconfig',
#  'encoderinfo',
#  'entropy',
#  'filename',
#  'filter',
#  'format',
#  'format_description',
#  'fp',
#  'frombytes',
#  'get_child_images',
#  'get_format_mimetype',
#  'getbands',
#  'getbbox',
#  'getchannel',
#  'getcolors',
#  'getdata',
#  'getexif',
#  'getextrema',
#  'getim',
#  'getpalette',
#  'getpixel',
#  'getprojection',
#  'getxmp',
#  'has_transparency_data',
#  'height',
#  'histogram',
#  'icclist',
#  'im',
#  'info',
#  'layer',
#  'layers',
#  'load',
#  'load_djpeg',
#  'load_end',
#  'load_prepare',
#  'load_read',
#  'map',
#  'mode',
#  'palette',
#  'paste',
#  'point',
#  'putalpha',
#  'putdata',
#  'putpalette',
#  'putpixel',
#  'quantization',
#  'quantize',
#  'readonly',
#  'reduce',
#  'remap_palette',
#  'resize',
#  'rotate',
#  'save',
#  'seek',
#  'show',
#  'size',
#  'split',
#  'tell',
#  'thumbnail',
#  'tile',
#  'tobitmap',
#  'tobytes',
#  'toqimage',
#  'toqpixmap',
#  'transform',
#  'transpose',
#  'verify',
#  'width']

# %%
"""
 'bits',
 'close',
 'convert',
 'copy',
 'crop',
 'entropy',
 'getchannel',
 'getcolors',
 'getdata',
 'getpixel',
 'height',
 'histogram',
 'info',
 'mode',
 'resize',
 'rotate',
 'save',
 'show',
 'size',
 'split',
 'thumbnail',
 'tobytes',
 'width'
"""
# Out:
# "\n 'bits',\n 'close',\n 'convert',\n 'copy',\n 'crop',\n 'entropy',\n 'getchannel',\n 'getcolors',\n 'getdata',\n 'getpixel',\n 'height',\n 'histogram',\n 'info',\n 'mode',\n 'resize',\n 'rotate',\n 'save',\n 'show',\n 'size',\n 'split',\n 'thumbnail',\n 'tobytes',\n 'width'\n"

# %%
# W, H
img.size
# Out:
# (284, 218)

# %%
img.width
# Out:
# 284

# %%
# 强行改变图像的size
img.resize(size=(100, 100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=284x218>

# %%
img.rotate(angle=-20)
# Out:
# <PIL.Image.Image image mode=RGB size=284x218>

# %%
img.convert(mode="L")
# Out:
# <PIL.Image.Image image mode=L size=284x218>

# %%
img.getpixel(xy=(100, 100))
# Out:
# (133, 148, 89)

# %%
np.array(img).shape
# Out:
# (218, 284, 3)

# %%
img1 = img.rotate(angle=10)

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGB size=284x218>

# %%
img1.save(fp="cat2.jpg")

# %% [markdown]
# ### 3. OpenCV

# %%
# 安装 
! pip install opencv-python -U
# Out:
# Requirement already satisfied: opencv-python in d:\software\anaconda\envs\py311\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in d:\software\anaconda\envs\py311\lib\site-packages (from opencv-python) (2.1.3)

# %%
# 1. 引入
import cv2

# %%
cv2.__version__
# Out:
# '4.11.0'

# %%
# 读取图像
img = cv2.imread(filename="cat.jpg")

# %%
# [H, W, C] BGR 模式
img.shape
# Out:
# (218, 284, 3)

# %%
img_r = img[:, :, -1]

# %%
# 显示图像（最好在VScode下使用）
# cv2.imshow(winname="cat", mat=img)
