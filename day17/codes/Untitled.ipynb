# %%
import pandas as pd

# %%
data = pd.read_csv(filepath_or_buffer="data.txt", sep="\t", header=None)

# %%
data
# Out:
#                                                        0  \
# 0                                                    Hi.
# 1                                                    Hi.
# 2                                                   Run.
# 3                                                  Stop!
# 4                                                  Wait!
# ...                                                  ...
# 29539  If you don't want to put on sunscreen, that's ...
# 29540  Even now, I occasionally think I'd like to see...
# 29541  It's very easy to sound natural in your own na...
# 29542  I got fired from the company, but since I have...
# 29543  If a person has not had a chance to acquire hi...
#
#                                                   1
# 0                                                嗨。
# 1                                               你好。
# 2                                             你用跑的。
# 3                                               住手！
# ...

# %%
data.sample(frac=0.8, random_state=0)
# Out:
#                                                   0               1
# 22695         Can we meet tomorrow morning at nine?    在明天早上九点见可以吗？
# 25297     Tom hasn't talked to Mary about that yet.     汤姆还没跟玛丽谈那事。
# 19878            He earned his living as a teacher.        他以当老师为生。
# 14706                I don't approve your decision.       我不同意你的决定。
# 20251            I'm so sorry I hurt your feelings.    我很抱歉伤害了你的感情。
# ...                                             ...             ...
# 23385        He betrayed her secret to his friends.  他把她的秘密告诉了他的朋友。
# 26323  She doesn't like people who aren't punctual.      她不喜欢不守时的人。
# 11608                   One's new. The other's old.   一个是新的，另一个是旧的。
# 13412                 He asked the man to help him.      他叫那个男人帮助他。
# 23943       Eating too much is bad for your health.      吃得太多对健康不好。
#
# [23635 rows x 2 columns]

# %%
data.to_numpy()
# Out:
# array([['Hi.', '嗨。'],
#        ['Hi.', '你好。'],
#        ['Run.', '你用跑的。'],
#        ...,
#        ["It's very easy to sound natural in your own native language, and very easy to sound unnatural in your non-native language.",
#         '你很容易把母语说得通顺流畅，却很容易把非母语说得不自然。'],
#        ["I got fired from the company, but since I have a little money saved up, for the time being, I won't have trouble with living expenses.",
#         '虽然我被公司解雇了，但是我还有点存款，所以目前不用担心生计问题。'],
#        ["If a person has not had a chance to acquire his target language by the time he's an adult, he's unlikely to be able to reach native speaker level in that language.",
#         '如果一个人在成人前没有机会习得目标语言，他对该语言的认识达到母语者程度的机会是相当小的。']], dtype=object)
